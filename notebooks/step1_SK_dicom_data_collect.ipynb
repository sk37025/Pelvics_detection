# %%
import os 

os.chdir("../")
from utils import display_Image_in_rows
from src.data import common
dataset_list = os.listdir(os.path.join(os.getcwd(),"data/raw/FRACTURE"))

# %%
dataset_path = [os.path.join(os.getcwd(),"data\\raw\\FRACTURE\\{}".format(i)) for i in dataset_list]

# %%
display_Image_in_rows(dataset_path[:12])

# %%
i_list =[]
not_i_list =[]
for i in dataset_path:
    if common.check_image_laterality(i) == "inversion":
        i_list.append(i)
    else:
        not_i_list.append(i)

# %%
print(len(not_i_list))
print(len(i_list))
# Out:
# 53
# 5

# %%
import pydicom

pydicom.read_file(i_list[0])
# Out:
# c:\Users\sk370\anaconda3\envs\dvc-cml\lib\site-packages\pydicom\valuerep.py:290: UserWarning: Invalid value for VR IS: '0.000000'. Please see <https://dicom.nema.org/medical/dicom/current/output/html/part05.html#table_6.2-1> for allowed values for each VR.
#   warnings.warn(msg)
# Dataset.file_meta -------------------------------
# (0002, 0000) File Meta Information Group Length  UL: 184
# (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
# (0002, 0002) Media Storage SOP Class UID         UI: Secondary Capture Image Storage
# (0002, 0003) Media Storage SOP Instance UID      UI: 1.2.410.114315.1.337.20130305220750.198126.2.463655
# (0002, 0010) Transfer Syntax UID                 UI: Implicit VR Little Endian
# (0002, 0012) Implementation Class UID            UI: 1.2.840.114257.0.1
# (0002, 0013) Implementation Version Name         SH: 'DEIT.2009.06.18'
# -------------------------------------------------
# (0008, 0000) Group Length                        UL: 392
# ...

# %%
print(i_list)
# Out:
# ['c:\\Users\\sk370\\Desktop\\AI-VOUCHER\\work\\Pelvics_detection\\data\\raw\\FRACTURE\\221 73F L.DCM', 'c:\\Users\\sk370\\Desktop\\AI-VOUCHER\\work\\Pelvics_detection\\data\\raw\\FRACTURE\\225 83F L.DCM', 'c:\\Users\\sk370\\Desktop\\AI-VOUCHER\\work\\Pelvics_detection\\data\\raw\\FRACTURE\\231 74F R.DCM', 'c:\\Users\\sk370\\Desktop\\AI-VOUCHER\\work\\Pelvics_detection\\data\\raw\\FRACTURE\\236 84M R.DCM', 'c:\\Users\\sk370\\Desktop\\AI-VOUCHER\\work\\Pelvics_detection\\data\\raw\\FRACTURE\\275 71F R.DCM']

# %%
display_Image_in_rows([i_list[0]])

# %%
display_Image_in_rows([i_list[1]])

# %%
display_Image_in_rows([i_list[2]])

# %%
display_Image_in_rows([i_list[3]])

# %%
display_Image_in_rows([i_list[4]])
